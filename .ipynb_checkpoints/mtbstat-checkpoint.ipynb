# %%
import pandas as pd
import xlrd

# %%
lenzerhede_mens = "./pdf2019/Lenzerheide_mens_2019.xlsx"
df = pd.read_excel(lenzerhede_mens)
df.head()
# Out:
#    Rank  BIB Last Name First Name Country                          Team  \
# 0   1.0    2   PIERRON     Amaury     FRA          COMMENCAL / VALLNORD
# 1   2.0    7   MINNAAR       Greg     RSA          SANTA CRUZ SYNDICATE
# 2   3.0    1     BRUNI       Loic     FRA           SPECIALIZED GRAVITY
# 3   4.0    3   BROSNAN       Troy     AUS  CANYON FACTORY DOWNHILL TEAM
# 4   5.0    5      HART      Danny     GBR  MADISON SARACEN FACTORY TEAM
#
#   Gender  Age  Phase  Heat        Result  IRM
# 0      M   23    NaN   NaN  00:02:49.422  NaN
# 1      M   38    NaN   NaN  00:02:50.373  NaN
# 2      M   25    NaN   NaN  00:02:50.822  NaN
# 3      M   26    NaN   NaN  00:02:51.582  NaN
# 4      M   28    NaN   NaN  00:02:52.644  NaN
